# %% [markdown]
# # Основы построения рекомендательных систем

# %% [markdown]
# ## Домашнее задание №4
# ### Основные пункты оценки
# 1. значение метрики на лидерборде
# 2. ревью кода в ноутбуке
# 3. реализация сервиса для модели
#
# Вы можете сделать **НЕ ВСЕ пункты и все равно получить 20 баллов**. Получение > 20 баллов будет расцениваться как 20.
#
# ### Подробности
# #### 1. Побейте метрику на лидерборде map@10 = 0.075 c моделью из implicit, lightfm или rectools, в том числе используя ANN **(5 баллов)**
# #### 2. Реализуйте эксперименты c моделями из implicit, lightfm или rectools, в том числе используя ANN. Результат - ноутбук(и) **(максимум 12 баллов)**
# Что можно сделать в ноутбуке:
# - Реализовать тюнинг гиперпараметров для моделей из implicit, lightfm или rectools **(3 балла)**
#   - Для перебора гиперпараметров можно использовать [`Optuna`](https://github.com/optuna/optuna), [`Hyperopt`](https://github.com/hyperopt/hyperopt)
# - Воспользоваться методом приближенного поиска соседей для выдачи рекомендаций. **(3 балла)**
#     - Можно использовать любые удобные: [`Annoy`](https://github.com/spotify/annoy), [`nmslib`](https://github.com/nmslib/nmslib) и.т.д
# - Сделать рекомендации для холодных пользователей используя их фичи (для кого нет фичей - там другим способом) **(3 балла)**
# - Провести эксперименты с параметрами оффлайн валидации и сделать выводы **(3 балла)**
#
# #### 3. Оберните модель в сервис **(максимум 12 баллов)**
# - Онлайн вариант: обучаете модель в ноутбуке, сохраняете обученную модель (pickle, dill), при запуске сервиса ее поднимаете и запрашиваете рекомендации "на лету" **(12 баллов)**
# - Оффлайн вариант: предварительно посчитайте рекомендации для всех пользователей, сохраните и запрашивайте их **(6 баллов)**
#
# ### Хороший pull request - это:
# - наличие описания (в идеале что сделано - по пунктам)
# - код по стандарту PEP8
# - легкая читаемость и воспроизводимость кода
# - комментарии и объяснения. В ipynb пользуйтесь силой маркдауна. В скриптах пишите комментарии и докстринг.
# - обоснование схемы валидации
# - анализ метрики качества

# %%
# установка библиотек
import sys
# !{sys.executable} -m pip install rectools[lightfm]
# !{sys.executable} -m pip install dill
# !{sys.executable} -m pip install optuna -q
# !{sys.executable} -m pip install nmslib
# Out:
# Requirement already satisfied: rectools[lightfm] in /opt/conda/lib/python3.10/site-packages (0.4.2)
# Requirement already satisfied: attrs<24.0.0,>=19.1.0 in /opt/conda/lib/python3.10/site-packages (from rectools[lightfm]) (23.1.0)
# Requirement already satisfied: implicit<0.8.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from rectools[lightfm]) (0.7.2)
# Requirement already satisfied: numpy<2.0.0,>=1.19.5 in /opt/conda/lib/python3.10/site-packages (from rectools[lightfm]) (1.24.3)
# Requirement already satisfied: pandas<2.0.0,>=0.25.3 in /opt/conda/lib/python3.10/site-packages (from rectools[lightfm]) (1.5.3)
# Requirement already satisfied: scipy<2.0.0,>=1.5.4 in /opt/conda/lib/python3.10/site-packages (from rectools[lightfm]) (1.11.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.27.0 in /opt/conda/lib/python3.10/site-packages (from rectools[lightfm]) (4.66.1)
# Requirement already satisfied: typeguard<3.0.0,>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from rectools[lightfm]) (2.13.3)
# Requirement already satisfied: lightfm<=1.17,>=1.16 in /opt/conda/lib/python3.10/site-packages (from rectools[lightfm]) (1.17)
# Requirement already satisfied: threadpoolctl in /opt/conda/lib/python3.10/site-packages (from implicit<0.8.0,>=0.7.1->rectools[lightfm]) (3.2.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from lightfm<=1.17,>=1.16->rectools[lightfm]) (2.31.0)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from lightfm<=1.17,>=1.16->rectools[lightfm]) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas<2.0.0,>=0.25.3->rectools[lightfm]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<2.0.0,>=0.25.3->rectools[lightfm]) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=0.25.3->rectools[lightfm]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->lightfm<=1.17,>=1.16->rectools[lightfm]) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->lightfm<=1.17,>=1.16->rectools[lightfm]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->lightfm<=1.17,>=1.16->rectools[lightfm]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->lightfm<=1.17,>=1.16->rectools[lightfm]) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->lightfm<=1.17,>=1.16->rectools[lightfm]) (1.3.2)
# Requirement already satisfied: dill in /opt/conda/lib/python3.10/site-packages (0.3.7)
# Collecting nmslib
#   Downloading nmslib-2.1.1.tar.gz (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 kB 1.4 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting pybind11<2.6.2 (from nmslib)
#   Using cached pybind11-2.6.1-py2.py3-none-any.whl (188 kB)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from nmslib) (5.9.3)
# Requirement already satisfied: numpy>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from nmslib) (1.24.3)
# Building wheels for collected packages: nmslib
#   Building wheel for nmslib (setup.py) ... done
#   Created wheel for nmslib: filename=nmslib-2.1.1-cp310-cp310-linux_x86_64.whl size=890848 sha256=3774c560c54812f58de142a002b181eaad6d79ffc879aa1e0c028083785fb830
#   Stored in directory: /root/.cache/pip/wheels/21/1a/5d/4cc754a5b1a88405cad184b76f823897a63a8d19afcd4b9314
# Successfully built nmslib
# Installing collected packages: pybind11, nmslib
#   Attempting uninstall: pybind11
#     Found existing installation: pybind11 2.11.1
#     Uninstalling pybind11-2.11.1:
#       Successfully uninstalled pybind11-2.11.1
# Successfully installed nmslib-2.1.1 pybind11-2.11.1

# %%
import os
import requests
from tqdm.auto import tqdm
import zipfile as zf
import dill

import pandas as pd
import numpy as np
from rectools import Columns
from rectools.dataset import Dataset
from rectools.metrics import MAP, MeanInvUserFreq, NDCG, Precision, Recall, Serendipity, calc_metrics
from rectools.model_selection import TimeRangeSplitter
from rectools.models import ImplicitALSWrapperModel, LightFMWrapperModel
from rectools.tools import UserToItemAnnRecommender

from implicit.als import AlternatingLeastSquares
from implicit.lmf import LogisticMatrixFactorization

from lightfm import LightFM

import optuna
import nmslib

import warnings
warnings.filterwarnings('ignore')

os.environ["OPENBLAS_NUM_THREADS"] = "1"  # For implicit ALS

# %%
# ВАЛИДАЦИЯ

# Функция валидирования моделей методом Leave-Time-out
def validate(models: dict, metrics: dict, splitter: TimeRangeSplitter, dataset: Dataset, K_RECOS: int):
  results = []

  # создаем итератор фолдов
  fold_iterator = splitter.split(dataset.interactions, collect_fold_stats=True)

  # обучение по фолдам
  for train_ids, test_ids, fold_info in tqdm((fold_iterator), total=splitter.n_splits):
      print(f"\n==================== Fold {fold_info['i_split']} ====================")
      print(fold_info)

      # тренировочная часть
      df_train = dataset.interactions.df.iloc[train_ids]
      train_dataset = Dataset.construct(df_train)

      # тестовая часть
      df_test = dataset.interactions.df.iloc[test_ids][Columns.UserItem]
      test_users = np.unique(df_test[Columns.User])

      # каталог
      catalog = df_train[Columns.Item].unique()


      # обучение моделей
      for model_name, model in models.items():
          # обучение и получение рекомендаций
          model.fit(train_dataset)
          recos = model.recommend(
              users=test_users,
              dataset=train_dataset,
              k=K_RECOS,
              filter_viewed=True,
          )
          # подсчет метрик
          metric_values = calc_metrics(
              metrics,
              reco=recos,
              interactions=df_test,
              prev_interactions=df_train,
              catalog=catalog,
          )
          # сохранение результатов
          res = {"fold": fold_info["i_split"], "model": model_name}
          res.update(metric_values)
          results.append(res)

  # форматирование в DataFrame
  pivot_results = pd.DataFrame(results)\
                    .drop(columns="fold")\
                    .groupby(["model"], sort=False)\
                    .agg("mean")
  # сохранение отчета
  pivot_results.to_csv('./report.csv')

  return pivot_results.style.highlight_max(color='green', axis=0)

# %%
# ПОДБОР ГИПЕРПАРАМЕТРОВ

# Функция подсчета метрики MAP@10
def calc_MAP10(model, dataset, train, test):
    metric = {"MAP@10": MAP(k=10) }
    
    test_users = np.unique(test[Columns.User])
    catalog = train[Columns.Item].unique()
    
    model.fit(dataset)
    recos = model.recommend(
        users=test_users,
        dataset=dataset,
        k=K_RECOS,
        filter_viewed=True
    )
    
    metric_values = calc_metrics(
        metric,
        reco=recos,
        interactions=test,
        prev_interactions=train,
        catalog=catalog,
      )
    
    return metric_values['MAP@10']


# Целевые функции Optuna
def objective_als(trial, dataset, train, test):
    factors=trial.suggest_int('factors', 10, 30, 10)
    iterations=trial.suggest_int('iterations', 10, 50, 10)
    
    model = ImplicitALSWrapperModel(
            model=AlternatingLeastSquares(
                factors=factors,
                iterations=iterations,
                num_threads=NUM_THREADS,
                random_state=RANDOM_STATE
            ),
        )
    return calc_MAP10(model, dataset, train, test)


def objective_logMF(trial, dataset, train, test):
    factors=trial.suggest_int('factors', 10, 30, 10)
    iterations=trial.suggest_int('iterations', 10, 50, 20)
    
    model = ImplicitALSWrapperModel(
            model=LogisticMatrixFactorization(
                factors=factors,
                iterations=iterations,
                num_threads=NUM_THREADS,
                random_state=RANDOM_STATE
            ),
        )
    return calc_MAP10(model, dataset, train, test)

        
def objective_lightFM(trial, dataset, train, test):
    no_components=trial.suggest_int('no_components', 10, 30, 10)
    loss=trial.suggest_categorical('loss', ['logistic', 'bpr', 'warp'])
    
    model = LightFMWrapperModel(
            LightFM(
                no_components=no_components,
                loss=loss,
                random_state=RANDOM_STATE,
            ),
            epochs=NUM_EPOCHS,
            num_threads=NUM_THREADS,
        )
    return calc_MAP10(model, dataset, train, test)

# %%
def augment_inner_product(factors):
    normed_factors = np.linalg.norm(factors, axis=1)
    max_norm = normed_factors.max()
    
    extra_dim = np.sqrt(max_norm ** 2 - normed_factors ** 2).reshape(-1, 1)
    augmented_factors = np.append(factors, extra_dim, axis=1)
    return max_norm, augmented_factors

# %% [markdown]
# ## Чтение данных

# %%
url = 'https://github.com/irsafilo/KION_DATASET/raw/f69775be31fa5779907cf0a92ddedb70037fb5ae/data_original.zip'
req = requests.get(url, stream=True)

with open('kion_train.zip', "wb") as fd:
    total_size_in_bytes = int(req.headers.get('Content-Length', 0))
    progress_bar = tqdm(desc='Downloading the kion dataset...',
                        total=total_size_in_bytes,
                        unit='iB', unit_scale=True)
    for chunk in req.iter_content(chunk_size=2 ** 20):
        progress_bar.update(len(chunk))
        fd.write(chunk)
# Out:
# Downloading the kion dataset...:   0%|          | 0.00/78.8M [00:00<?, ?iB/s]

# %%
# Разархивирование данных
files = zf.ZipFile('kion_train.zip','r')
files.extractall()
files.close()

# %%
# Чтение в DataFrame
users = pd.read_csv('data_original/users.csv')
items = pd.read_csv('data_original/items.csv')

interactions = pd.read_csv('data_original/interactions.csv', parse_dates=["last_watch_dt"])
interactions.rename(
    columns={
        'last_watch_dt': Columns.Datetime,
        'total_dur': Columns.Weight
    },
    inplace=True)

# %% [markdown]
# ## Подбор гиперпараметров и валидация
# Для экспериментов будет использоваться часть датасета из 1 000 000 записей о взаимодействиях с фильтрацией холодных пользователей.

# %%
# Тренеровочная и тестовая выборки
interactions_sm = interactions.iloc[:1000000]

max_date = interactions_sm[Columns.Datetime].max()

train = interactions_sm[interactions_sm[Columns.Datetime] < max_date - pd.Timedelta(days=7)].copy()
test = interactions_sm[interactions_sm[Columns.Datetime] >= max_date - pd.Timedelta(days=7)].copy()

print(f"train: {train.shape}")
print(f"test: {test.shape}")
# Out:
# train: (910259, 5)
# test: (89741, 5)

# %%
# Отфильтруем холодных пользователей из теста
cold_users = set(test[Columns.User]) - set(train[Columns.User])
test.drop(test[test[Columns.User].isin(cold_users)].index, inplace=True)

# %%
# Сформируем датасет
dataset = Dataset.construct(interactions_df=train)

# %% [markdown]
# ## 1. Подбор гиперпараметров моделей

# %%
RANDOM_STATE = 42
NUM_THREADS = 4
NUM_EPOCHS = 10
K_RECOS = 10

# %%
study_als = optuna.create_study(study_name='AlternatingLeastSquares Optuna Optimization', direction='maximize')
study_als.optimize(lambda trial: objective_als(trial, dataset, train, test), n_trials=20, n_jobs=-1)
# Out:
# [I 2023-12-10 12:03:14,561] A new study created in memory with name: AlternatingLeastSquares Optuna Optimization
# [I 2023-12-10 12:03:57,784] Trial 2 finished with value: 0.013344147032424107 and parameters: {'factors': 20, 'iterations': 20}. Best is trial 2 with value: 0.013344147032424107.
# [I 2023-12-10 12:04:11,864] Trial 1 finished with value: 0.015325705735661931 and parameters: {'factors': 10, 'iterations': 40}. Best is trial 1 with value: 0.015325705735661931.
# [I 2023-12-10 12:04:14,414] Trial 0 finished with value: 0.017838438383127445 and parameters: {'factors': 20, 'iterations': 50}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:04:17,099] Trial 3 finished with value: 0.017838438383127445 and parameters: {'factors': 20, 'iterations': 50}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:04:38,166] Trial 4 finished with value: 0.014264689164555491 and parameters: {'factors': 30, 'iterations': 20}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:04:48,444] Trial 5 finished with value: 0.00920698783915194 and parameters: {'factors': 10, 'iterations': 10}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:04:58,265] Trial 6 finished with value: 0.016779543821243463 and parameters: {'factors': 20, 'iterations': 40}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:05:04,683] Trial 7 finished with value: 0.0162991919323279 and parameters: {'factors': 10, 'iterations': 50}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:05:19,869] Trial 8 finished with value: 0.01559216258506367 and parameters: {'factors': 30, 'iterations': 40}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:05:30,085] Trial 9 finished with value: 0.013969166786196354 and parameters: {'factors': 10, 'iterations': 30}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:05:41,078] Trial 10 finished with value: 0.0162991919323279 and parameters: {'factors': 10, 'iterations': 50}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:05:48,570] Trial 11 finished with value: 0.0162991919323279 and parameters: {'factors': 10, 'iterations': 50}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:05:56,412] Trial 12 finished with value: 0.00920698783915194 and parameters: {'factors': 10, 'iterations': 10}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:06:13,013] Trial 13 finished with value: 0.016117228296226124 and parameters: {'factors': 30, 'iterations': 50}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:06:24,290] Trial 14 finished with value: 0.017838438383127445 and parameters: {'factors': 20, 'iterations': 50}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:06:32,135] Trial 15 finished with value: 0.017838438383127445 and parameters: {'factors': 20, 'iterations': 50}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:06:43,109] Trial 16 finished with value: 0.017838438383127445 and parameters: {'factors': 20, 'iterations': 50}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:06:55,190] Trial 17 finished with value: 0.016779543821243463 and parameters: {'factors': 20, 'iterations': 40}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:07:02,294] Trial 19 finished with value: 0.015319158231650984 and parameters: {'factors': 20, 'iterations': 30}. Best is trial 0 with value: 0.017838438383127445.
# [I 2023-12-10 12:07:02,305] Trial 18 finished with value: 0.015319158231650984 and parameters: {'factors': 20, 'iterations': 30}. Best is trial 0 with value: 0.017838438383127445.

# %%
study_als.best_params
# Out:
# {'factors': 20, 'iterations': 50}

# %%
study_logMF = optuna.create_study(study_name='LogisticMatrixFactorization Optuna Optimization', direction='maximize')
study_logMF.optimize(lambda trial: objective_logMF(trial, dataset, train, test), n_trials=20, n_jobs=-1)
# Out:
# [I 2023-12-10 12:07:02,312] A new study created in memory with name: LogisticMatrixFactorization Optuna Optimization
# [I 2023-12-10 12:07:25,020] Trial 1 finished with value: 0.0001458842225366093 and parameters: {'factors': 10, 'iterations': 10}. Best is trial 1 with value: 0.0001458842225366093.
# [I 2023-12-10 12:08:06,972] Trial 3 finished with value: 0.0004168586268534732 and parameters: {'factors': 10, 'iterations': 50}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:08:21,944] Trial 0 finished with value: 0.00019787586060213773 and parameters: {'factors': 20, 'iterations': 30}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:09:14,286] Trial 6 finished with value: 0.00031265482503162076 and parameters: {'factors': 10, 'iterations': 30}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:09:22,715] Trial 2 finished with value: 0.00023360539932723142 and parameters: {'factors': 20, 'iterations': 50}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:09:25,525] Trial 4 finished with value: 0.0002131625302887301 and parameters: {'factors': 30, 'iterations': 30}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:09:58,115] Trial 7 finished with value: 0.0002117441707082885 and parameters: {'factors': 30, 'iterations': 10}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:10:22,136] Trial 5 finished with value: 0.00023360539932723142 and parameters: {'factors': 20, 'iterations': 50}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:10:26,736] Trial 9 finished with value: 0.0002117441707082885 and parameters: {'factors': 30, 'iterations': 10}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:10:26,766] Trial 8 finished with value: 0.0002117441707082885 and parameters: {'factors': 30, 'iterations': 10}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:11:18,782] Trial 10 finished with value: 0.00019787586060213773 and parameters: {'factors': 20, 'iterations': 30}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:11:26,187] Trial 11 finished with value: 0.00031265482503162076 and parameters: {'factors': 10, 'iterations': 30}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:11:29,466] Trial 12 finished with value: 0.0002117441707082885 and parameters: {'factors': 30, 'iterations': 10}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:11:35,219] Trial 13 finished with value: 0.0004168586268534732 and parameters: {'factors': 10, 'iterations': 50}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:12:20,378] Trial 14 finished with value: 0.0004168586268534732 and parameters: {'factors': 10, 'iterations': 50}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:12:37,061] Trial 15 finished with value: 0.0004168586268534732 and parameters: {'factors': 10, 'iterations': 50}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:12:47,720] Trial 16 finished with value: 0.0004168586268534732 and parameters: {'factors': 10, 'iterations': 50}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:12:49,582] Trial 17 finished with value: 0.0004168586268534732 and parameters: {'factors': 10, 'iterations': 50}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:13:09,503] Trial 18 finished with value: 0.0004168586268534732 and parameters: {'factors': 10, 'iterations': 50}. Best is trial 3 with value: 0.0004168586268534732.
# [I 2023-12-10 12:13:20,380] Trial 19 finished with value: 0.0004168586268534732 and parameters: {'factors': 10, 'iterations': 50}. Best is trial 3 with value: 0.0004168586268534732.

# %%
study_logMF.best_params
# Out:
# {'factors': 10, 'iterations': 50}

# %%
study_lightFM = optuna.create_study(study_name='LightFM Optuna Optimization', direction='maximize')
study_lightFM.optimize(lambda trial: objective_lightFM(trial, dataset, train, test), n_trials=20, n_jobs=-1)
# Out:
# [I 2023-12-10 12:13:20,388] A new study created in memory with name: LightFM Optuna Optimization
# [I 2023-12-10 12:14:07,893] Trial 2 finished with value: 0.04154694247261958 and parameters: {'no_components': 10, 'loss': 'warp'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:14:10,712] Trial 0 finished with value: 1.106482376211166e-05 and parameters: {'no_components': 10, 'loss': 'bpr'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:14:15,527] Trial 3 finished with value: 0.00031510194195429216 and parameters: {'no_components': 30, 'loss': 'logistic'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:14:19,726] Trial 1 finished with value: 1.1452539958627698e-05 and parameters: {'no_components': 30, 'loss': 'bpr'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:14:38,982] Trial 5 finished with value: 3.667539581989109e-05 and parameters: {'no_components': 10, 'loss': 'logistic'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:14:59,867] Trial 4 finished with value: 0.0 and parameters: {'no_components': 20, 'loss': 'bpr'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:15:12,230] Trial 7 finished with value: 6.710472632008417e-06 and parameters: {'no_components': 10, 'loss': 'bpr'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:15:16,197] Trial 6 finished with value: 0.03979419268252773 and parameters: {'no_components': 30, 'loss': 'warp'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:15:20,774] Trial 8 finished with value: 2.305846214884416e-05 and parameters: {'no_components': 10, 'loss': 'logistic'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:15:32,389] Trial 9 finished with value: 0.0412914394883259 and parameters: {'no_components': 10, 'loss': 'warp'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:16:09,699] Trial 10 finished with value: 0.0 and parameters: {'no_components': 20, 'loss': 'bpr'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:16:12,302] Trial 12 finished with value: 2.1102606298766833e-05 and parameters: {'no_components': 10, 'loss': 'bpr'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:16:15,757] Trial 11 finished with value: 0.039464784109475605 and parameters: {'no_components': 20, 'loss': 'warp'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:16:21,591] Trial 13 finished with value: 0.040356588776638086 and parameters: {'no_components': 20, 'loss': 'warp'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:17:06,314] Trial 16 finished with value: 0.041233039104049636 and parameters: {'no_components': 10, 'loss': 'warp'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:17:11,217] Trial 17 finished with value: 0.041071937964222226 and parameters: {'no_components': 10, 'loss': 'warp'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:17:11,265] Trial 14 finished with value: 0.040607597017024426 and parameters: {'no_components': 20, 'loss': 'warp'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:17:11,271] Trial 15 finished with value: 0.039726167520017196 and parameters: {'no_components': 20, 'loss': 'warp'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:17:34,479] Trial 18 finished with value: 0.04064672490545734 and parameters: {'no_components': 10, 'loss': 'warp'}. Best is trial 2 with value: 0.04154694247261958.
# [I 2023-12-10 12:17:37,478] Trial 19 finished with value: 0.04022240988727766 and parameters: {'no_components': 20, 'loss': 'warp'}. Best is trial 2 with value: 0.04154694247261958.

# %%
study_lightFM.best_params
# Out:
# {'no_components': 10, 'loss': 'warp'}

# %% [markdown]
# ## 2. Валидация

# %%
metrics = {
    "prec@1": Precision(k=1),
    "prec@5": Precision(k=5),
    "prec@10": Precision(k=10),
    "recall@1": Recall(k=1),
    "recall@5": Recall(k=5),
    "recall@10": Recall(k=10),
    "MAP@1": MAP(k=1),
    "MAP@5": MAP(k=5),
    "MAP@10": MAP(k=10),
    "NDCG@1": MAP(k=1),
    "NDCG@5": MAP(k=5),
    "NDCG@10": MAP(k=10),
    "MeanInvUserFreq@1": MeanInvUserFreq(k=1),
    "MeanInvUserFreq@5": MeanInvUserFreq(k=5),
    "MeanInvUserFreq@10": MeanInvUserFreq(k=10),
    "Serendipity@1": Serendipity(k=1),
    "Serendipity@5": Serendipity(k=5),
    "Serendipity@10": Serendipity(k=10),
}

# %%
models = {'ALS': ImplicitALSWrapperModel(
                    model=AlternatingLeastSquares(**study_als.best_params)
                  ),
          'LogMF': ImplicitALSWrapperModel(
                      model=LogisticMatrixFactorization(**study_logMF.best_params)
                  ),
          'LightFM': LightFMWrapperModel(
                      model=LightFM(**study_lightFM.best_params),
                      epochs=NUM_EPOCHS,
                      num_threads=NUM_THREADS
                      )
         }

# %% [markdown]
# Эксперимент №1.
# - Кол-во фолдов 3
# - Размер тестового фолда 7D

# %%
n_splits = 3
cv = TimeRangeSplitter(test_size="7D",
                        n_splits=n_splits,
                        filter_cold_users=True,
                        filter_cold_items=True,
                        filter_already_seen=True)

# %%
validate(models, metrics, cv, dataset, K_RECOS=10)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ==================== Fold 0 ====================
# {'i_split': 0, 'start': Timestamp('2021-07-25 00:00:00', freq='7D'), 'end': Timestamp('2021-08-01 00:00:00', freq='7D'), 'train': 701298, 'train_users': 329509, 'train_items': 10774, 'test': 32728, 'test_users': 22701, 'test_items': 3788}
#
# ==================== Fold 1 ====================
# {'i_split': 1, 'start': Timestamp('2021-08-01 00:00:00', freq='7D'), 'end': Timestamp('2021-08-08 00:00:00', freq='7D'), 'train': 768221, 'train_users': 355896, 'train_items': 10931, 'test': 33489, 'test_users': 23467, 'test_items': 3769}
#
# ==================== Fold 2 ====================
# {'i_split': 2, 'start': Timestamp('2021-08-08 00:00:00', freq='7D'), 'end': Timestamp('2021-08-15 00:00:00', freq='7D'), 'train': 838173, 'train_users': 382886, 'train_items': 11184, 'test': 36223, 'test_users': 25023, 'test_items': 3887}
# <style type="text/css">
# #T_12015_row0_col15, #T_12015_row0_col16, #T_12015_row0_col17, #T_12015_row1_col12, #T_12015_row1_col13, #T_12015_row1_col14, #T_12015_row2_col0, #T_12015_row2_col1, #T_12015_row2_col2, #T_12015_row2_col3, #T_12015_row2_col4, #T_12015_row2_col5, #T_12015_row2_col6, #T_12015_row2_col7, #T_12015_row2_col8, #T_12015_row2_col9, #T_12015_row2_col10, #T_12015_row2_col11 {
#   background-color: green;
# }
# </style>
# <table id="T_12015">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12015_level0_col0" class="col_heading level0 col0" >prec@1</th>
#       <th id="T_12015_level0_col1" class="col_heading level0 col1" >recall@1</th>
#       <th id="T_12015_level0_col2" class="col_heading level0 col2" >prec@5</th>
#       <th id="T_12015_level0_col3" class="col_heading level0 col3" >recall@5</th>
#       <th id="T_12015_level0_col4" class="col_heading level0 col4" >prec@10</th>
#       <th id="T_12015_level0_col5" class="col_heading level0 col5" >recall@10</th>
#       <th id="T_12015_level0_col6" class="col_heading level0 col6" >MAP@1</th>
#       <th id="T_12015_level0_col7" class="col_heading level0 col7" >MAP@5</th>
#       <th id="T_12015_level0_col8" class="col_heading level0 col8" >MAP@10</th>
#       <th id="T_12015_level0_col9" class="col_heading level0 col9" >NDCG@1</th>
#       <th id="T_12015_level0_col10" class="col_heading level0 col10" >NDCG@5</th>
#       <th id="T_12015_level0_col11" class="col_heading level0 col11" >NDCG@10</th>
#       <th id="T_12015_level0_col12" class="col_heading level0 col12" >MeanInvUserFreq@1</th>
#       <th id="T_12015_level0_col13" class="col_heading level0 col13" >MeanInvUserFreq@5</th>
#       <th id="T_12015_level0_col14" class="col_heading level0 col14" >MeanInvUserFreq@10</th>
#       <th id="T_12015_level0_col15" class="col_heading level0 col15" >Serendipity@1</th>
#       <th id="T_12015_level0_col16" class="col_heading level0 col16" >Serendipity@5</th>
#       <th id="T_12015_level0_col17" class="col_heading level0 col17" >Serendipity@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12015_level0_row0" class="row_heading level0 row0" >ALS</th>
#       <td id="T_12015_row0_col0" class="data row0 col0" >0.011774</td>
#       <td id="T_12015_row0_col1" class="data row0 col1" >0.009488</td>
#       <td id="T_12015_row0_col2" class="data row0 col2" >0.007081</td>
#       <td id="T_12015_row0_col3" class="data row0 col3" >0.027982</td>
#       <td id="T_12015_row0_col4" class="data row0 col4" >0.005482</td>
#       <td id="T_12015_row0_col5" class="data row0 col5" >0.042821</td>
#       <td id="T_12015_row0_col6" class="data row0 col6" >0.009488</td>
#       <td id="T_12015_row0_col7" class="data row0 col7" >0.016006</td>
#       <td id="T_12015_row0_col8" class="data row0 col8" >0.017971</td>
#       <td id="T_12015_row0_col9" class="data row0 col9" >0.009488</td>
#       <td id="T_12015_row0_col10" class="data row0 col10" >0.016006</td>
#       <td id="T_12015_row0_col11" class="data row0 col11" >0.017971</td>
#       <td id="T_12015_row0_col12" class="data row0 col12" >6.294636</td>
#       <td id="T_12015_row0_col13" class="data row0 col13" >7.300418</td>
#       <td id="T_12015_row0_col14" class="data row0 col14" >7.808022</td>
#       <td id="T_12015_row0_col15" class="data row0 col15" >0.000012</td>
#       <td id="T_12015_row0_col16" class="data row0 col16" >0.000016</td>
#       <td id="T_12015_row0_col17" class="data row0 col17" >0.000018</td>
#     </tr>
#     <tr>
#       <th id="T_12015_level0_row1" class="row_heading level0 row1" >LogMF</th>
#       <td id="T_12015_row1_col0" class="data row1 col0" >0.000198</td>
#       <td id="T_12015_row1_col1" class="data row1 col1" >0.000126</td>
#       <td id="T_12015_row1_col2" class="data row1 col2" >0.000190</td>
#       <td id="T_12015_row1_col3" class="data row1 col3" >0.000580</td>
#       <td id="T_12015_row1_col4" class="data row1 col4" >0.000202</td>
#       <td id="T_12015_row1_col5" class="data row1 col5" >0.001294</td>
#       <td id="T_12015_row1_col6" class="data row1 col6" >0.000126</td>
#       <td id="T_12015_row1_col7" class="data row1 col7" >0.000272</td>
#       <td id="T_12015_row1_col8" class="data row1 col8" >0.000366</td>
#       <td id="T_12015_row1_col9" class="data row1 col9" >0.000126</td>
#       <td id="T_12015_row1_col10" class="data row1 col10" >0.000272</td>
#       <td id="T_12015_row1_col11" class="data row1 col11" >0.000366</td>
#       <td id="T_12015_row1_col12" class="data row1 col12" >13.556276</td>
#       <td id="T_12015_row1_col13" class="data row1 col13" >13.624578</td>
#       <td id="T_12015_row1_col14" class="data row1 col14" >13.663741</td>
#       <td id="T_12015_row1_col15" class="data row1 col15" >0.000008</td>
#       <td id="T_12015_row1_col16" class="data row1 col16" >0.000007</td>
#       <td id="T_12015_row1_col17" class="data row1 col17" >0.000007</td>
#     </tr>
#     <tr>
#       <th id="T_12015_level0_row2" class="row_heading level0 row2" >LightFM</th>
#       <td id="T_12015_row2_col0" class="data row2 col0" >0.024932</td>
#       <td id="T_12015_row2_col1" class="data row2 col1" >0.020885</td>
#       <td id="T_12015_row2_col2" class="data row2 col2" >0.019462</td>
#       <td id="T_12015_row2_col3" class="data row2 col3" >0.079261</td>
#       <td id="T_12015_row2_col4" class="data row2 col4" >0.013737</td>
#       <td id="T_12015_row2_col5" class="data row2 col5" >0.110036</td>
#       <td id="T_12015_row2_col6" class="data row2 col6" >0.020885</td>
#       <td id="T_12015_row2_col7" class="data row2 col7" >0.040866</td>
#       <td id="T_12015_row2_col8" class="data row2 col8" >0.045148</td>
#       <td id="T_12015_row2_col9" class="data row2 col9" >0.020885</td>
#       <td id="T_12015_row2_col10" class="data row2 col10" >0.040866</td>
#       <td id="T_12015_row2_col11" class="data row2 col11" >0.045148</td>
#       <td id="T_12015_row2_col12" class="data row2 col12" >3.987654</td>
#       <td id="T_12015_row2_col13" class="data row2 col13" >4.633913</td>
#       <td id="T_12015_row2_col14" class="data row2 col14" >5.395589</td>
#       <td id="T_12015_row2_col15" class="data row2 col15" >0.000003</td>
#       <td id="T_12015_row2_col16" class="data row2 col16" >0.000004</td>
#       <td id="T_12015_row2_col17" class="data row2 col17" >0.000004</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# По большенству метрик выигрывает LightFM[warp], в том числе по ключевой метрике MAP@10. LogisticMF показывает хорошие результаты для метрики novelty, а ALS - для serendipity.

# %% [markdown]
# Эксперимент №2.
# - Кол-во фолдов 5
# - Размер тестового фолда 7D

# %%
n_splits = 5
cv = TimeRangeSplitter(test_size="7D",
                        n_splits=n_splits,
                        filter_cold_users=True,
                        filter_cold_items=True,
                        filter_already_seen=True)

# %%
validate(models, metrics, cv, dataset, K_RECOS=10)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ==================== Fold 0 ====================
# {'i_split': 0, 'start': Timestamp('2021-07-11 00:00:00', freq='7D'), 'end': Timestamp('2021-07-18 00:00:00', freq='7D'), 'train': 583565, 'train_users': 282499, 'train_items': 10376, 'test': 27422, 'test_users': 19466, 'test_items': 3464}
#
# ==================== Fold 1 ====================
# {'i_split': 1, 'start': Timestamp('2021-07-18 00:00:00', freq='7D'), 'end': Timestamp('2021-07-25 00:00:00', freq='7D'), 'train': 640331, 'train_users': 305483, 'train_items': 10619, 'test': 29886, 'test_users': 20780, 'test_items': 3684}
#
# ==================== Fold 2 ====================
# {'i_split': 2, 'start': Timestamp('2021-07-25 00:00:00', freq='7D'), 'end': Timestamp('2021-08-01 00:00:00', freq='7D'), 'train': 701298, 'train_users': 329509, 'train_items': 10774, 'test': 32728, 'test_users': 22701, 'test_items': 3788}
#
# ==================== Fold 3 ====================
# {'i_split': 3, 'start': Timestamp('2021-08-01 00:00:00', freq='7D'), 'end': Timestamp('2021-08-08 00:00:00', freq='7D'), 'train': 768221, 'train_users': 355896, 'train_items': 10931, 'test': 33489, 'test_users': 23467, 'test_items': 3769}
#
# ==================== Fold 4 ====================
# {'i_split': 4, 'start': Timestamp('2021-08-08 00:00:00', freq='7D'), 'end': Timestamp('2021-08-15 00:00:00', freq='7D'), 'train': 838173, 'train_users': 382886, 'train_items': 11184, 'test': 36223, 'test_users': 25023, 'test_items': 3887}
# <style type="text/css">
# #T_181d4_row0_col15, #T_181d4_row0_col16, #T_181d4_row0_col17, #T_181d4_row1_col12, #T_181d4_row1_col13, #T_181d4_row1_col14, #T_181d4_row2_col0, #T_181d4_row2_col1, #T_181d4_row2_col2, #T_181d4_row2_col3, #T_181d4_row2_col4, #T_181d4_row2_col5, #T_181d4_row2_col6, #T_181d4_row2_col7, #T_181d4_row2_col8, #T_181d4_row2_col9, #T_181d4_row2_col10, #T_181d4_row2_col11 {
#   background-color: green;
# }
# </style>
# <table id="T_181d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_181d4_level0_col0" class="col_heading level0 col0" >prec@1</th>
#       <th id="T_181d4_level0_col1" class="col_heading level0 col1" >recall@1</th>
#       <th id="T_181d4_level0_col2" class="col_heading level0 col2" >prec@5</th>
#       <th id="T_181d4_level0_col3" class="col_heading level0 col3" >recall@5</th>
#       <th id="T_181d4_level0_col4" class="col_heading level0 col4" >prec@10</th>
#       <th id="T_181d4_level0_col5" class="col_heading level0 col5" >recall@10</th>
#       <th id="T_181d4_level0_col6" class="col_heading level0 col6" >MAP@1</th>
#       <th id="T_181d4_level0_col7" class="col_heading level0 col7" >MAP@5</th>
#       <th id="T_181d4_level0_col8" class="col_heading level0 col8" >MAP@10</th>
#       <th id="T_181d4_level0_col9" class="col_heading level0 col9" >NDCG@1</th>
#       <th id="T_181d4_level0_col10" class="col_heading level0 col10" >NDCG@5</th>
#       <th id="T_181d4_level0_col11" class="col_heading level0 col11" >NDCG@10</th>
#       <th id="T_181d4_level0_col12" class="col_heading level0 col12" >MeanInvUserFreq@1</th>
#       <th id="T_181d4_level0_col13" class="col_heading level0 col13" >MeanInvUserFreq@5</th>
#       <th id="T_181d4_level0_col14" class="col_heading level0 col14" >MeanInvUserFreq@10</th>
#       <th id="T_181d4_level0_col15" class="col_heading level0 col15" >Serendipity@1</th>
#       <th id="T_181d4_level0_col16" class="col_heading level0 col16" >Serendipity@5</th>
#       <th id="T_181d4_level0_col17" class="col_heading level0 col17" >Serendipity@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_181d4_level0_row0" class="row_heading level0 row0" >ALS</th>
#       <td id="T_181d4_row0_col0" class="data row0 col0" >0.011692</td>
#       <td id="T_181d4_row0_col1" class="data row0 col1" >0.009493</td>
#       <td id="T_181d4_row0_col2" class="data row0 col2" >0.007748</td>
#       <td id="T_181d4_row0_col3" class="data row0 col3" >0.031086</td>
#       <td id="T_181d4_row0_col4" class="data row0 col4" >0.005853</td>
#       <td id="T_181d4_row0_col5" class="data row0 col5" >0.046256</td>
#       <td id="T_181d4_row0_col6" class="data row0 col6" >0.009493</td>
#       <td id="T_181d4_row0_col7" class="data row0 col7" >0.016859</td>
#       <td id="T_181d4_row0_col8" class="data row0 col8" >0.018887</td>
#       <td id="T_181d4_row0_col9" class="data row0 col9" >0.009493</td>
#       <td id="T_181d4_row0_col10" class="data row0 col10" >0.016859</td>
#       <td id="T_181d4_row0_col11" class="data row0 col11" >0.018887</td>
#       <td id="T_181d4_row0_col12" class="data row0 col12" >6.385426</td>
#       <td id="T_181d4_row0_col13" class="data row0 col13" >7.278217</td>
#       <td id="T_181d4_row0_col14" class="data row0 col14" >7.785989</td>
#       <td id="T_181d4_row0_col15" class="data row0 col15" >0.000010</td>
#       <td id="T_181d4_row0_col16" class="data row0 col16" >0.000016</td>
#       <td id="T_181d4_row0_col17" class="data row0 col17" >0.000017</td>
#     </tr>
#     <tr>
#       <th id="T_181d4_level0_row1" class="row_heading level0 row1" >LogMF</th>
#       <td id="T_181d4_row1_col0" class="data row1 col0" >0.000155</td>
#       <td id="T_181d4_row1_col1" class="data row1 col1" >0.000096</td>
#       <td id="T_181d4_row1_col2" class="data row1 col2" >0.000213</td>
#       <td id="T_181d4_row1_col3" class="data row1 col3" >0.000653</td>
#       <td id="T_181d4_row1_col4" class="data row1 col4" >0.000223</td>
#       <td id="T_181d4_row1_col5" class="data row1 col5" >0.001477</td>
#       <td id="T_181d4_row1_col6" class="data row1 col6" >0.000096</td>
#       <td id="T_181d4_row1_col7" class="data row1 col7" >0.000282</td>
#       <td id="T_181d4_row1_col8" class="data row1 col8" >0.000386</td>
#       <td id="T_181d4_row1_col9" class="data row1 col9" >0.000096</td>
#       <td id="T_181d4_row1_col10" class="data row1 col10" >0.000282</td>
#       <td id="T_181d4_row1_col11" class="data row1 col11" >0.000386</td>
#       <td id="T_181d4_row1_col12" class="data row1 col12" >13.517182</td>
#       <td id="T_181d4_row1_col13" class="data row1 col13" >13.532958</td>
#       <td id="T_181d4_row1_col14" class="data row1 col14" >13.556483</td>
#       <td id="T_181d4_row1_col15" class="data row1 col15" >0.000005</td>
#       <td id="T_181d4_row1_col16" class="data row1 col16" >0.000007</td>
#       <td id="T_181d4_row1_col17" class="data row1 col17" >0.000007</td>
#     </tr>
#     <tr>
#       <th id="T_181d4_level0_row2" class="row_heading level0 row2" >LightFM</th>
#       <td id="T_181d4_row2_col0" class="data row2 col0" >0.026268</td>
#       <td id="T_181d4_row2_col1" class="data row2 col1" >0.021940</td>
#       <td id="T_181d4_row2_col2" class="data row2 col2" >0.020714</td>
#       <td id="T_181d4_row2_col3" class="data row2 col3" >0.084997</td>
#       <td id="T_181d4_row2_col4" class="data row2 col4" >0.014761</td>
#       <td id="T_181d4_row2_col5" class="data row2 col5" >0.119345</td>
#       <td id="T_181d4_row2_col6" class="data row2 col6" >0.021940</td>
#       <td id="T_181d4_row2_col7" class="data row2 col7" >0.043672</td>
#       <td id="T_181d4_row2_col8" class="data row2 col8" >0.048420</td>
#       <td id="T_181d4_row2_col9" class="data row2 col9" >0.021940</td>
#       <td id="T_181d4_row2_col10" class="data row2 col10" >0.043672</td>
#       <td id="T_181d4_row2_col11" class="data row2 col11" >0.048420</td>
#       <td id="T_181d4_row2_col12" class="data row2 col12" >3.982964</td>
#       <td id="T_181d4_row2_col13" class="data row2 col13" >4.665888</td>
#       <td id="T_181d4_row2_col14" class="data row2 col14" >5.412196</td>
#       <td id="T_181d4_row2_col15" class="data row2 col15" >0.000003</td>
#       <td id="T_181d4_row2_col16" class="data row2 col16" >0.000003</td>
#       <td id="T_181d4_row2_col17" class="data row2 col17" >0.000004</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Изменение валидационных параметров не привело к новым лидерам по метрикам, все алгоритмы сохранили свои позиции. Сами же значения метрик так же не испытали значительных изменений.

# %% [markdown]
# Эксперимент №3
# - Кол-во фолдов 5
# - Размер тестового фолда 3D

# %%
n_splits = 5
cv = TimeRangeSplitter(test_size="3D",
                        n_splits=n_splits,
                        filter_cold_users=True,
                        filter_cold_items=True,
                        filter_already_seen=True)

# %%
validate(models, metrics, cv, dataset, K_RECOS=10)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ==================== Fold 0 ====================
# {'i_split': 0, 'start': Timestamp('2021-07-31 00:00:00', freq='3D'), 'end': Timestamp('2021-08-03 00:00:00', freq='3D'), 'train': 757473, 'train_users': 351548, 'train_items': 10905, 'test': 16405, 'test_users': 12855, 'test_items': 2894}
#
# ==================== Fold 1 ====================
# {'i_split': 1, 'start': Timestamp('2021-08-03 00:00:00', freq='3D'), 'end': Timestamp('2021-08-06 00:00:00', freq='3D'), 'train': 789369, 'train_users': 364141, 'train_items': 11015, 'test': 15104, 'test_users': 11911, 'test_items': 2814}
#
# ==================== Fold 2 ====================
# {'i_split': 2, 'start': Timestamp('2021-08-06 00:00:00', freq='3D'), 'end': Timestamp('2021-08-09 00:00:00', freq='3D'), 'train': 817604, 'train_users': 374994, 'train_items': 11123, 'test': 17042, 'test_users': 13390, 'test_items': 2927}
#
# ==================== Fold 3 ====================
# {'i_split': 3, 'start': Timestamp('2021-08-09 00:00:00', freq='3D'), 'end': Timestamp('2021-08-12 00:00:00', freq='3D'), 'train': 849356, 'train_users': 387156, 'train_items': 11202, 'test': 15966, 'test_users': 12594, 'test_items': 2901}
#
# ==================== Fold 4 ====================
# {'i_split': 4, 'start': Timestamp('2021-08-12 00:00:00', freq='3D'), 'end': Timestamp('2021-08-15 00:00:00', freq='3D'), 'train': 878624, 'train_users': 398110, 'train_items': 11290, 'test': 17128, 'test_users': 13316, 'test_items': 2960}
# <style type="text/css">
# #T_5c82b_row0_col15, #T_5c82b_row0_col16, #T_5c82b_row0_col17, #T_5c82b_row1_col12, #T_5c82b_row1_col13, #T_5c82b_row1_col14, #T_5c82b_row2_col0, #T_5c82b_row2_col1, #T_5c82b_row2_col2, #T_5c82b_row2_col3, #T_5c82b_row2_col4, #T_5c82b_row2_col5, #T_5c82b_row2_col6, #T_5c82b_row2_col7, #T_5c82b_row2_col8, #T_5c82b_row2_col9, #T_5c82b_row2_col10, #T_5c82b_row2_col11 {
#   background-color: green;
# }
# </style>
# <table id="T_5c82b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c82b_level0_col0" class="col_heading level0 col0" >prec@1</th>
#       <th id="T_5c82b_level0_col1" class="col_heading level0 col1" >recall@1</th>
#       <th id="T_5c82b_level0_col2" class="col_heading level0 col2" >prec@5</th>
#       <th id="T_5c82b_level0_col3" class="col_heading level0 col3" >recall@5</th>
#       <th id="T_5c82b_level0_col4" class="col_heading level0 col4" >prec@10</th>
#       <th id="T_5c82b_level0_col5" class="col_heading level0 col5" >recall@10</th>
#       <th id="T_5c82b_level0_col6" class="col_heading level0 col6" >MAP@1</th>
#       <th id="T_5c82b_level0_col7" class="col_heading level0 col7" >MAP@5</th>
#       <th id="T_5c82b_level0_col8" class="col_heading level0 col8" >MAP@10</th>
#       <th id="T_5c82b_level0_col9" class="col_heading level0 col9" >NDCG@1</th>
#       <th id="T_5c82b_level0_col10" class="col_heading level0 col10" >NDCG@5</th>
#       <th id="T_5c82b_level0_col11" class="col_heading level0 col11" >NDCG@10</th>
#       <th id="T_5c82b_level0_col12" class="col_heading level0 col12" >MeanInvUserFreq@1</th>
#       <th id="T_5c82b_level0_col13" class="col_heading level0 col13" >MeanInvUserFreq@5</th>
#       <th id="T_5c82b_level0_col14" class="col_heading level0 col14" >MeanInvUserFreq@10</th>
#       <th id="T_5c82b_level0_col15" class="col_heading level0 col15" >Serendipity@1</th>
#       <th id="T_5c82b_level0_col16" class="col_heading level0 col16" >Serendipity@5</th>
#       <th id="T_5c82b_level0_col17" class="col_heading level0 col17" >Serendipity@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c82b_level0_row0" class="row_heading level0 row0" >ALS</th>
#       <td id="T_5c82b_row0_col0" class="data row0 col0" >0.009117</td>
#       <td id="T_5c82b_row0_col1" class="data row0 col1" >0.007895</td>
#       <td id="T_5c82b_row0_col2" class="data row0 col2" >0.006282</td>
#       <td id="T_5c82b_row0_col3" class="data row0 col3" >0.027033</td>
#       <td id="T_5c82b_row0_col4" class="data row0 col4" >0.004894</td>
#       <td id="T_5c82b_row0_col5" class="data row0 col5" >0.041512</td>
#       <td id="T_5c82b_row0_col6" class="data row0 col6" >0.007895</td>
#       <td id="T_5c82b_row0_col7" class="data row0 col7" >0.014595</td>
#       <td id="T_5c82b_row0_col8" class="data row0 col8" >0.016492</td>
#       <td id="T_5c82b_row0_col9" class="data row0 col9" >0.007895</td>
#       <td id="T_5c82b_row0_col10" class="data row0 col10" >0.014595</td>
#       <td id="T_5c82b_row0_col11" class="data row0 col11" >0.016492</td>
#       <td id="T_5c82b_row0_col12" class="data row0 col12" >6.377705</td>
#       <td id="T_5c82b_row0_col13" class="data row0 col13" >7.316436</td>
#       <td id="T_5c82b_row0_col14" class="data row0 col14" >7.836277</td>
#       <td id="T_5c82b_row0_col15" class="data row0 col15" >0.000010</td>
#       <td id="T_5c82b_row0_col16" class="data row0 col16" >0.000015</td>
#       <td id="T_5c82b_row0_col17" class="data row0 col17" >0.000017</td>
#     </tr>
#     <tr>
#       <th id="T_5c82b_level0_row1" class="row_heading level0 row1" >LogMF</th>
#       <td id="T_5c82b_row1_col0" class="data row1 col0" >0.000214</td>
#       <td id="T_5c82b_row1_col1" class="data row1 col1" >0.000154</td>
#       <td id="T_5c82b_row1_col2" class="data row1 col2" >0.000193</td>
#       <td id="T_5c82b_row1_col3" class="data row1 col3" >0.000759</td>
#       <td id="T_5c82b_row1_col4" class="data row1 col4" >0.000190</td>
#       <td id="T_5c82b_row1_col5" class="data row1 col5" >0.001472</td>
#       <td id="T_5c82b_row1_col6" class="data row1 col6" >0.000154</td>
#       <td id="T_5c82b_row1_col7" class="data row1 col7" >0.000357</td>
#       <td id="T_5c82b_row1_col8" class="data row1 col8" >0.000449</td>
#       <td id="T_5c82b_row1_col9" class="data row1 col9" >0.000154</td>
#       <td id="T_5c82b_row1_col10" class="data row1 col10" >0.000357</td>
#       <td id="T_5c82b_row1_col11" class="data row1 col11" >0.000449</td>
#       <td id="T_5c82b_row1_col12" class="data row1 col12" >13.802431</td>
#       <td id="T_5c82b_row1_col13" class="data row1 col13" >13.800061</td>
#       <td id="T_5c82b_row1_col14" class="data row1 col14" >13.814133</td>
#       <td id="T_5c82b_row1_col15" class="data row1 col15" >0.000006</td>
#       <td id="T_5c82b_row1_col16" class="data row1 col16" >0.000007</td>
#       <td id="T_5c82b_row1_col17" class="data row1 col17" >0.000006</td>
#     </tr>
#     <tr>
#       <th id="T_5c82b_level0_row2" class="row_heading level0 row2" >LightFM</th>
#       <td id="T_5c82b_row2_col0" class="data row2 col0" >0.021581</td>
#       <td id="T_5c82b_row2_col1" class="data row2 col1" >0.019451</td>
#       <td id="T_5c82b_row2_col2" class="data row2 col2" >0.017000</td>
#       <td id="T_5c82b_row2_col3" class="data row2 col3" >0.074318</td>
#       <td id="T_5c82b_row2_col4" class="data row2 col4" >0.012158</td>
#       <td id="T_5c82b_row2_col5" class="data row2 col5" >0.105232</td>
#       <td id="T_5c82b_row2_col6" class="data row2 col6" >0.019451</td>
#       <td id="T_5c82b_row2_col7" class="data row2 col7" >0.038214</td>
#       <td id="T_5c82b_row2_col8" class="data row2 col8" >0.042437</td>
#       <td id="T_5c82b_row2_col9" class="data row2 col9" >0.019451</td>
#       <td id="T_5c82b_row2_col10" class="data row2 col10" >0.038214</td>
#       <td id="T_5c82b_row2_col11" class="data row2 col11" >0.042437</td>
#       <td id="T_5c82b_row2_col12" class="data row2 col12" >4.057236</td>
#       <td id="T_5c82b_row2_col13" class="data row2 col13" >4.688568</td>
#       <td id="T_5c82b_row2_col14" class="data row2 col14" >5.449004</td>
#       <td id="T_5c82b_row2_col15" class="data row2 col15" >0.000003</td>
#       <td id="T_5c82b_row2_col16" class="data row2 col16" >0.000003</td>
#       <td id="T_5c82b_row2_col17" class="data row2 col17" >0.000005</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Результаты эксперимента аналогичны эксперименту №2.\
# Таким образом, по результам 3-х экспериментов лучшие значения для большинства метрик и для метрики MAP@10 показал алгоритм LightFM[warp].

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# Используется алгоритм LightFM[warp]. \
# Добавим user и item признаки в процесс обучения модели.\
# Для ускорения выдачи рекомендаций используется ANN.

# %% [markdown]
# ### User features

# %%
users.fillna('Unknown', inplace=True)
users = users.loc[users[Columns.User].isin(interactions[Columns.User])].copy()

user_features_frames = []
for feature in ["sex", "age", "income"]:
    feature_frame = users.reindex(columns=[Columns.User, feature])
    feature_frame.columns = ["id", "value"]
    feature_frame["feature"] = feature
    user_features_frames.append(feature_frame)
user_features = pd.concat(user_features_frames)

# %% [markdown]
# ### Item features

# %%
items = items.loc[items[Columns.Item].isin(interactions[Columns.Item])].copy()

items["genre"] = items["genres"].str.lower().str.replace(", ", ",", regex=False).str.split(",")
genre_feature = items[["item_id", "genre"]].explode("genre")
genre_feature.columns = ["id", "value"]
genre_feature["feature"] = "genre"

content_feature = items.reindex(columns=[Columns.Item, "content_type"])
content_feature.columns = ["id", "value"]
content_feature["feature"] = "content_type"

item_features = pd.concat((genre_feature, content_feature))

# %%
# Сформируем датасет с признаками users и items
dataset = Dataset.construct(
    interactions_df=interactions,
    user_features_df=user_features,
    cat_user_features=["sex", "age", "income"],
    item_features_df=item_features,
    cat_item_features=["genre", "content_type"],
)

# %% [markdown]
# ### Валидация

# %%
model = {'LightFM': LightFMWrapperModel(
              model=LightFM(**study_lightFM.best_params),
              epochs=NUM_EPOCHS,
              num_threads=NUM_THREADS
          )
        }

metric = {"MAP@10": MAP(k=10)}

# %%
n_splits = 3
cv = TimeRangeSplitter(test_size="7D",
                        n_splits=n_splits,
                        filter_cold_users=True,
                        filter_cold_items=True,
                        filter_already_seen=True)

# %%
validate(model, metrics, cv, dataset, K_RECOS=10)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ==================== Fold 0 ====================
# {'i_split': 0, 'start': Timestamp('2021-08-02 00:00:00', freq='7D'), 'end': Timestamp('2021-08-09 00:00:00', freq='7D'), 'train': 4266013, 'train_users': 797423, 'train_items': 15237, 'test': 263681, 'test_users': 98184, 'test_items': 6602}
#
# ==================== Fold 1 ====================
# {'i_split': 1, 'start': Timestamp('2021-08-09 00:00:00', freq='7D'), 'end': Timestamp('2021-08-16 00:00:00', freq='7D'), 'train': 4649162, 'train_users': 850489, 'train_items': 15415, 'test': 279422, 'test_users': 103511, 'test_items': 6698}
#
# ==================== Fold 2 ====================
# {'i_split': 2, 'start': Timestamp('2021-08-16 00:00:00', freq='7D'), 'end': Timestamp('2021-08-23 00:00:00', freq='7D'), 'train': 5051815, 'train_users': 906071, 'train_items': 15577, 'test': 298878, 'test_users': 110076, 'test_items': 6679}
# <style type="text/css">
# #T_ab712_row0_col0, #T_ab712_row0_col1, #T_ab712_row0_col2, #T_ab712_row0_col3, #T_ab712_row0_col4, #T_ab712_row0_col5, #T_ab712_row0_col6, #T_ab712_row0_col7, #T_ab712_row0_col8, #T_ab712_row0_col9, #T_ab712_row0_col10, #T_ab712_row0_col11, #T_ab712_row0_col12, #T_ab712_row0_col13, #T_ab712_row0_col14, #T_ab712_row0_col15, #T_ab712_row0_col16, #T_ab712_row0_col17 {
#   background-color: green;
# }
# </style>
# <table id="T_ab712">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab712_level0_col0" class="col_heading level0 col0" >prec@1</th>
#       <th id="T_ab712_level0_col1" class="col_heading level0 col1" >recall@1</th>
#       <th id="T_ab712_level0_col2" class="col_heading level0 col2" >prec@5</th>
#       <th id="T_ab712_level0_col3" class="col_heading level0 col3" >recall@5</th>
#       <th id="T_ab712_level0_col4" class="col_heading level0 col4" >prec@10</th>
#       <th id="T_ab712_level0_col5" class="col_heading level0 col5" >recall@10</th>
#       <th id="T_ab712_level0_col6" class="col_heading level0 col6" >MAP@1</th>
#       <th id="T_ab712_level0_col7" class="col_heading level0 col7" >MAP@5</th>
#       <th id="T_ab712_level0_col8" class="col_heading level0 col8" >MAP@10</th>
#       <th id="T_ab712_level0_col9" class="col_heading level0 col9" >NDCG@1</th>
#       <th id="T_ab712_level0_col10" class="col_heading level0 col10" >NDCG@5</th>
#       <th id="T_ab712_level0_col11" class="col_heading level0 col11" >NDCG@10</th>
#       <th id="T_ab712_level0_col12" class="col_heading level0 col12" >MeanInvUserFreq@1</th>
#       <th id="T_ab712_level0_col13" class="col_heading level0 col13" >MeanInvUserFreq@5</th>
#       <th id="T_ab712_level0_col14" class="col_heading level0 col14" >MeanInvUserFreq@10</th>
#       <th id="T_ab712_level0_col15" class="col_heading level0 col15" >Serendipity@1</th>
#       <th id="T_ab712_level0_col16" class="col_heading level0 col16" >Serendipity@5</th>
#       <th id="T_ab712_level0_col17" class="col_heading level0 col17" >Serendipity@10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab712_level0_row0" class="row_heading level0 row0" >LightFM</th>
#       <td id="T_ab712_row0_col0" class="data row0 col0" >0.087207</td>
#       <td id="T_ab712_row0_col1" class="data row0 col1" >0.047629</td>
#       <td id="T_ab712_row0_col2" class="data row0 col2" >0.052926</td>
#       <td id="T_ab712_row0_col3" class="data row0 col3" >0.135297</td>
#       <td id="T_ab712_row0_col4" class="data row0 col4" >0.036547</td>
#       <td id="T_ab712_row0_col5" class="data row0 col5" >0.179547</td>
#       <td id="T_ab712_row0_col6" class="data row0 col6" >0.047629</td>
#       <td id="T_ab712_row0_col7" class="data row0 col7" >0.080945</td>
#       <td id="T_ab712_row0_col8" class="data row0 col8" >0.087976</td>
#       <td id="T_ab712_row0_col9" class="data row0 col9" >0.047629</td>
#       <td id="T_ab712_row0_col10" class="data row0 col10" >0.080945</td>
#       <td id="T_ab712_row0_col11" class="data row0 col11" >0.087976</td>
#       <td id="T_ab712_row0_col12" class="data row0 col12" >3.049181</td>
#       <td id="T_ab712_row0_col13" class="data row0 col13" >3.819135</td>
#       <td id="T_ab712_row0_col14" class="data row0 col14" >4.503419</td>
#       <td id="T_ab712_row0_col15" class="data row0 col15" >0.000037</td>
#       <td id="T_ab712_row0_col16" class="data row0 col16" >0.000038</td>
#       <td id="T_ab712_row0_col17" class="data row0 col17" >0.000042</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Обучение модели

# %%
model['LightFM'].fit(dataset)

# %% [markdown]
# ### ANN

# %%
user_vectors, item_vectors = model['LightFM'].get_vectors(dataset)

ann_model = UserToItemAnnRecommender(
    user_vectors=user_vectors,
    item_vectors=item_vectors,
    user_id_map=dataset.user_id_map,
    item_id_map=dataset.item_id_map,
)

ann_model.fit()

# %%
list(ann_model.get_item_list_for_user(user_id=5, top_n=K_RECOS))
# Out:
# [5115, 4179, 7825, 14302, 1404, 13995, 7653, 12316, 12593, 13468]

# %%
with open('model.dill', 'wb') as f:
    dill.dump(model, f)
